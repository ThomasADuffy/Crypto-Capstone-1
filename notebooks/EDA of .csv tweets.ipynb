# %%
from pprint import pprint
import time
import numpy as np
import pandas as pd
import getpass
from ..src import parsing_class
ETHtweets =  crypto_csv_tweets(f"/media/{getpass.getuser()}/extra/Crypto-Capstone-1/data/ETH-tweets/ETHtweets.csv")
BTCtweets = crypto_csv_tweets(f"/media/{getpass.getuser()}/extra/Crypto-Capstone-1/data/BTC-tweets/BTC.csv")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-0fca8b85deab> in <module>
#       4 import pandas as pd
#       5 import getpass
# ----> 6 from ..src import parsing_class
#       7 ETHtweets =  crypto_csv_tweets(f"/media/{getpass.getuser()}/extra/Crypto-Capstone-1/data/ETH-tweets/ETHtweets.csv")
#       8 BTCtweets = crypto_csv_tweets(f"/media/{getpass.getuser()}/extra/Crypto-Capstone-1/data/BTC-tweets/BTC.csv")
#
# ValueError: attempted relative import beyond top-level package

# %%
BTCtweets.data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4897156 entries, 0 to 4897155
# Data columns (total 23 columns):
# tweet_id                  int64
# conversation_id           int64
# author_id                 int64
# author_name               object
# isverified                int64
# datetime                  object
# language                  object
# tweet_text                object
# replies                   int64
# retweets                  int64
# favorites                 int64
# mentions                  object
# hashtags                  object
# permalink                 object
# urls                      object
# ispartofconversation      int64
# isreply                   int64
# isretweet                 int64
# reply_to_user_id          float64
# reply_to_user_name        object
# quoted_tweet_id           float64
# quoted_tweet_user_name    object
# quoted_tweet_user_id      float64
# dtypes: float64(3), int64(10), object(10)
# memory usage: 859.3+ MB

# %%
BTCtweets.data.head()
# Out:
#               tweet_id      conversation_id           author_id  \
# 0  1049449336726122497  1049449336726122497  767253595716661248
# 1  1049449307043024896  1049449307043024896           768679436
# 2  1049449278194769920  1049449278194769920           808146374
# 3  1049449198771470336  1049449198771470336  849237156010786819
# 4  1049449160129343488  1049449160129343488          1466726246
#
#        author_name  isverified    datetime language  \
# 0      sirarthur04           0  2018-10-08      und
# 1        tapatrade           0  2018-10-08      und
# 2  AutolottoscratR           0  2018-10-08      und
# 3       otc_cyborg           0  2018-10-08       en
# 4        Coinboard           0  2018-10-08       en
#
#                                           tweet_text  replies  retweets  ...  \
# 0  #BitcoinOne #BTCONE #Bounty #Bitcoin #Ethereum...        0         0  ...
# 1  #bitcoin https://twitter.com/MustStopMurad/sta...        0         0  ...
# 2  #Autolottoscratchr #autolotto #worldsfirstscra...        0         0  ...
# 3  UK Telecoms Regulator Receives Grant to Deploy...        0         0  ...
# 4  Electron Cash Developer Reveals In-Wallet BCH ...        0         0  ...
#
#                                      permalink  \
# 0      /sirarthur04/status/1049449336726122497
# 1        /tapatrade/status/1049449307043024896
# 2  /AutolottoscratR/status/1049449278194769920
# 3       /otc_cyborg/status/1049449198771470336
# 4        /Coinboard/status/1049449160129343488
#
#                                                 urls ispartofconversation  \
# 0  https://twitter.com/THEBITCOINONE/status/10493...                    0
# 1  https://twitter.com/MustStopMurad/status/10221...                    0
# 2  https://www.instagram.com/p/BosQITMHHsa/?utm_s...                    0
# 3                             https://ift.tt/2Og4951                    0
# 4                      http://twib.in/l/9MKRadjK6Mod                    0
#
#   isreply isretweet  reply_to_user_id  reply_to_user_name  quoted_tweet_id  \
# 0       0         1               NaN                 NaN     1.049322e+18
# 1       0         1               NaN                 NaN     1.022170e+18
# 2       0         0               NaN                 NaN              NaN
# 3       0         0               NaN                 NaN              NaN
# 4       0         0               NaN                 NaN              NaN
#
#    quoted_tweet_user_name quoted_tweet_user_id
# 0           THEBITCOINONE         9.416432e+17
# 1           MustStopMurad         8.443046e+17
# 2                     NaN                  NaN
# 3                     NaN                  NaN
# 4                     NaN                  NaN
#
# [5 rows x 23 columns]

# %%
BTCtweets.data.describe()
# Out:
#            tweet_id  conversation_id     author_id    isverified  \
# count  4.897156e+06     4.897156e+06  4.897156e+06  4.897156e+06
# mean   9.799385e+17     9.798617e+17  4.354351e+17  1.551819e-02
# std    3.890705e+16     3.908563e+16  4.535875e+17  1.236017e-01
# min    9.170303e+17     3.148255e+08  2.100000e+01  0.000000e+00
# 25%    9.453107e+17     9.452870e+17  1.093161e+09  0.000000e+00
# 50%    9.767369e+17     9.767077e+17  4.329154e+09  0.000000e+00
# 75%    1.016667e+18     1.016642e+18  9.180179e+17  0.000000e+00
# max    1.049449e+18     1.049449e+18  1.049447e+18  1.000000e+00
#
#             replies      retweets     favorites  ispartofconversation  \
# count  4.897156e+06  4.897156e+06  4.897156e+06          4.897156e+06
# mean   3.891969e-01  1.413259e+00  2.426264e+00          3.186135e-02
# std    1.302262e+01  2.923208e+01  3.321360e+01          1.756309e-01
# min    0.000000e+00  0.000000e+00  0.000000e+00          0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00          0.000000e+00
# 50%    0.000000e+00  0.000000e+00  0.000000e+00          0.000000e+00
# 75%    0.000000e+00  0.000000e+00  1.000000e+00          0.000000e+00
# max    6.183000e+03  1.683800e+04  1.964700e+04          1.000000e+00
#
#             isreply     isretweet  reply_to_user_id  quoted_tweet_id  \
# count  4.897156e+06  4.897156e+06      1.175450e+05     4.210900e+05
# mean   2.511621e-02  9.230071e-02      3.247818e+17     9.938126e+17
# std    1.564781e-01  2.894500e-01      4.383222e+17     4.088153e+16
# min    0.000000e+00  0.000000e+00      1.200000e+01     9.800000e+01
# 25%    0.000000e+00  0.000000e+00      1.187564e+08     9.732427e+17
# 50%    0.000000e+00  0.000000e+00      2.207129e+09     1.000434e+18
# 75%    0.000000e+00  0.000000e+00      8.877480e+17     1.020983e+18
# max    1.000000e+00  1.000000e+00      1.047477e+18     1.049442e+18
#
#        quoted_tweet_user_id
# count          4.210900e+05
# mean           6.793604e+17
# std            4.194951e+17
# min            1.200000e+01
# 25%            3.160617e+09
# 50%            9.274561e+17
# 75%            9.630886e+17
# max            1.048881e+18

# %%
ETHtweets.data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3758572 entries, 0 to 3758571
# Data columns (total 22 columns):
# tweet_id                  int64
# conversation_id           int64
# author_id                 int64
# author_name               object
# isverified                int64
# datetime                  object
# tweet_text                object
# replies                   int64
# retweets                  int64
# favorites                 int64
# mentions                  object
# hashtags                  object
# permalink                 object
# urls                      object
# ispartofconversation      int64
# isreply                   int64
# isretweet                 int64
# reply_to_user_id          float64
# reply_to_user_name        object
# quoted_tweet_id           float64
# quoted_tweet_user_name    object
# quoted_tweet_user_id      float64
# dtypes: float64(3), int64(10), object(9)
# memory usage: 630.9+ MB

# %%
ETHtweets.data.head()
# Out:
#               tweet_id      conversation_id           author_id  \
# 0  1024444451639451653  1024444451639451653          2276587183
# 1  1024444283363962880  1024444283363962880  963657116782419970
# 2  1024444257116057600  1024444257116057600           259856497
# 3  1024444244830969857  1024444244830969857            46092203
# 4  1024444219778203650  1024444219778203650  953111456332984321
#
#      author_name  isverified    datetime  \
# 0  coinspectator           0  2018-07-31
# 1      drewawise           1  2018-07-31
# 2      BeerdHead           0  2018-07-31
# 3    maransa2006           0  2018-07-31
# 4  CereloMasilag           0  2018-07-31
#
#                                           tweet_text  replies  retweets  \
# 0  Shopin Continues to Make Blockchain History: P...        0         0
# 1  You must see this video about #TRON $ trx #btc...        0         4
# 2  Dear all of $ Crypto Let HIM HEAR IT Hope My M...        1         0
# 3  This tweet; "TOP 10 PRICES DECEMBER Show you'r...        0         0
# 4  CYDER Token Telegram Airdrop we are airdroping...        0         0
#
#    favorites  ...                                  permalink  \
# 0          0  ...  /coinspectator/status/1024444451639451653
# 1         12  ...      /drewawise/status/1024444283363962880
# 2          3  ...      /BeerdHead/status/1024444257116057600
# 3          0  ...    /maransa2006/status/1024444244830969857
# 4          0  ...  /CereloMasilag/status/1024444219778203650
#
#                                                 urls ispartofconversation  \
# 0  https://coinspectator.com/news/684586/shopin-c...                    0
# 1  https://twitter.com/justinsuntron/status/10242...                    0
# 2  https://twitter.com/RudyHavenstein/status/1024...                    0
# 3                                                NaN                    0
# 4                https://telegram.me/Cyder_token_bot                    0
#
#   isreply  isretweet  reply_to_user_id  reply_to_user_name  quoted_tweet_id  \
# 0       0          0               NaN                 NaN              NaN
# 1       0          1               NaN                 NaN     1.024226e+18
# 2       0          1               NaN                 NaN     1.024442e+18
# 3       0          0               NaN                 NaN              NaN
# 4       0          0               NaN                 NaN              NaN
#
#   quoted_tweet_user_name  quoted_tweet_user_id
# 0                    NaN                   NaN
# 1          justinsuntron          9.028390e+17
# 2         RudyHavenstein          1.358146e+09
# 3                    NaN                   NaN
# 4                    NaN                   NaN
#
# [5 rows x 22 columns]

# %%
ETHtweets.data.describe()
# Out:
#            tweet_id  conversation_id     author_id    isverified  \
# count  3.758572e+06     3.758572e+06  3.758572e+06  3.758572e+06
# mean   9.573853e+17     9.573448e+17  5.133036e+17  9.846559e-03
# std    6.744656e+16     6.748275e+16  4.476774e+17  9.874010e-02
# min    6.272719e+17     6.402164e+16  2.100000e+01  0.000000e+00
# 25%    9.394280e+17     9.393882e+17  2.232163e+09  0.000000e+00
# 50%    9.791352e+17     9.790990e+17  7.826293e+17  0.000000e+00
# 75%    1.000220e+18     1.000198e+18  9.321333e+17  0.000000e+00
# max    1.024444e+18     1.024444e+18  1.024346e+18  1.000000e+00
#
#             replies      retweets     favorites  ispartofconversation  \
# count  3.758572e+06  3.758572e+06  3.758572e+06          3.758572e+06
# mean   4.769051e-01  2.474671e+00  2.870640e+00          2.278046e-02
# std    2.143572e+01  5.248792e+01  4.860418e+01          1.492029e-01
# min    0.000000e+00  0.000000e+00  0.000000e+00          0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00          0.000000e+00
# 50%    0.000000e+00  0.000000e+00  0.000000e+00          0.000000e+00
# 75%    0.000000e+00  0.000000e+00  1.000000e+00          0.000000e+00
# max    1.130800e+04  1.839000e+04  1.637500e+04          1.000000e+00
#
#             isreply     isretweet  reply_to_user_id  quoted_tweet_id  \
# count  3.758572e+06  3.758572e+06      7.153300e+04     6.410490e+05
# mean   1.986792e-02  1.880922e-01      5.427760e+17     9.849443e+17
# std    1.395464e-01  3.907858e-01      4.623968e+17     3.974830e+16
# min    0.000000e+00  0.000000e+00      1.200000e+01     7.800000e+01
# 25%    0.000000e+00  0.000000e+00      9.614454e+08     9.772231e+17
# 50%    0.000000e+00  0.000000e+00      8.762862e+17     9.932696e+17
# 75%    0.000000e+00  0.000000e+00      9.588147e+17     1.005400e+18
# max    1.000000e+00  1.000000e+00      1.023806e+18     1.024442e+18
#
#        quoted_tweet_user_id
# count          6.410490e+05
# mean           8.066762e+17
# std            3.293228e+17
# min            1.200000e+01
# 25%            8.978274e+17
# 50%            9.336415e+17
# 75%            9.622931e+17
# max            1.023731e+18

# %%
BTCtweets.print_min_max_datetime()
# Out:
# The oldest tweet is: 2017-10-08
# The youngest tweet is: 2018-10-08

# %%
ETHtweets.print_min_max_datetime()
# Out:
# The oldest tweet is: 2015-07-31
# The youngest tweet is: 2018-07-31

# %%
BTCtweets.date_filter('2017-10-08','2018-02-10')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-c9f854cd49af> in <module>
# ----> 1 BTCtweets.date_filter('10--2017','2018-02-10')
#
# ~/Documents/Galvanize/Capstones/Crypto-Capstone-1/parsing_class.py in date_filter(self, startdate, enddate)
#     113     def date_filter(self,startdate,enddate):
#     114         ''' Note: startdate and enddate must be a string and formated like 12-25-2018'''
# --> 115         self.data=self.data[(self.data['datetime'] > startdate) & (self.data['datetime'] < enddate)]
#     116
#     117     def count_tweets_by_day(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#    1764
#    1765             with np.errstate(all='ignore'):
# -> 1766                 res = na_op(values, other)
#    1767             if is_scalar(res):
#    1768                 raise TypeError('Could not compare {typ} type with Series'
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in na_op(x, y)
#    1623
#    1624         if is_object_dtype(x.dtype):
# -> 1625             result = _comp_method_OBJECT_ARRAY(op, x, y)
#    1626
#    1627         elif is_datetimelike_v_numeric(x, y):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in _comp_method_OBJECT_ARRAY(op, x, y)
#    1601         result = libops.vec_compare(x, y, op)
#    1602     else:
# -> 1603         result = libops.scalar_compare(x, y, op)
#    1604     return result
#    1605
#
# pandas/_libs/ops.pyx in pandas._libs.ops.scalar_compare()
#
# TypeError: '>' not supported between instances of 'datetime.date' and 'str'

# %%
BTCtweets.data.head()
